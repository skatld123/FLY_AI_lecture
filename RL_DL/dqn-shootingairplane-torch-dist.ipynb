# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r drive/MyDrive/Test/SKT/gym_examples/gym_examples /content

# %% [markdown]
# # DQN으로 Shooring Airplane Game 강화학습
#
# 먼저 여러가지 설정 변수 정의

# %%
import numpy as np
import gym
import torch
import torch.nn as nn
import torchvision.transforms as T

# Configuration paramaters for the whole setup
seed = 42
gamma = 0.99  # Discount factor for past rewards
epsilon = 1.0  # Epsilon greedy parameter
epsilon_min = 0.1  # Minimum epsilon greedy parameter
epsilon_max = 1.0  # Maximum epsilon greedy parameter
epsilon_interval = epsilon_max - epsilon_min # Rate at which to reduce chance
                                             # of random action being taken
batch_size = 16  # Size of batch taken from replay buffer
max_steps_per_episode = 60
max_episodes = 5000

# %% [markdown]
# ### 게임 환경 설정
#
# 상태(state) 정의
# - 보드판의 모양: (8 * 8) 행렬 * 3 채널
# - 채널 0: unseen
# - 채널 1: hit
# - 채녈 2: miss
#
# 액션 정의
# - 돌의 가능한 위치 (8 * 8 = 64)

# %%
env = gym.make('gym_examples:gym_examples/ShootingAirplane-v0', render_mode="text")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# env에서 정의한 action_space, observation_space 의 모양 확인
# - action_space: 3개의 값의 튜플 (벡터)
# - observation_space: HWC 형태의 이미지 (마지막 축이 단일 값인 15 * 15 * 1 텐서) -> pytorch를 사용할 경우 적절히 1 * 15 * 15 텐서로 수정필요

# %%
env.action_space.shape
# Out:
# (2,)

# %%
env.observation_space.shape
# Out:
# (8, 8, 1)

# %% [markdown]
# ### 네트워크 정의하기
#
# 참고: Conv2d 파라미터
# * in_channels (int) – Number of channels in the input image
# * out_channels (int) – Number of channels produced by the convolution
# * kernel_size (int or tuple) – Size of the convolving kernel
# * stride (int or tuple, optional) – Stride of the convolution. Default: 1
# * padding (int, tuple or str, optional) – Padding added to all four sides of the input. Default: 0
# * padding_mode (str, optional) – 'zeros', 'reflect', 'replicate' or 'circular'. Default: 'zeros'

# %%
import torch
import torch.nn as nn

num_actions = 64

class QModel(nn.Module):
    def __init__(self, num_actions):
        super(QModel, self).__init__()
        self.dropout = nn.Dropout(p=0.3)
        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding='same')
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding='same')
        self.conv3 = nn.Conv2d(32, 32, kernel_size=3, stride=1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(1152, 512)
        self.fc2 = nn.Linear(512, num_actions)

    def forward(self, x):
        x = nn.functional.relu(self.conv1(x))
        x = nn.functional.relu(self.conv2(x))
        x = self.dropout(x)
        x = nn.functional.relu(self.conv3(x))
        x = self.flatten(x)
        x = nn.functional.relu(self.fc1(x))
        x = self.dropout(x)
        action = self.fc2(x)
        return action

# %% [markdown]
# ### 모델 빌딩 & 로스 및 최적화 계산기 만들기

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# The first model makes the predictions for Q-values which are used to
# make a action.
model = QModel(num_actions)
model.to(device)

# Build a target model for the prediction of future rewards.
# The weights of a target model get updated every 10000 steps thus when the
# loss between the Q-values is calculated the target Q-value is stable.
model_target = QModel(num_actions)
model_target.to(device)

loss_function = nn.SmoothL1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.00025)

# %%
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### Replay Buffer 정의

# %%
# Experience replay buffers
action_history = []
action_mask_history = []
state_history = []
state_next_history = []
rewards_history = []
done_history = []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0

# Number of frames to take random action and observe output
epsilon_random_frames = 50000
# Number of frames for exploration
epsilon_greedy_frames = 200000.0
# Maximum replay length
# Note: The Deepmind paper suggests 1000000 however this causes memory issues
max_memory_length = 500000
# Train the model after 4 actions
update_after_actions = 4
# How often to update the target network
update_target_network = 10000

# %% [markdown]
# ### 전처리
#
# - env가 리턴하는 observation은 일단 np.array이니 torch.tensor로 캐스팅
# - env가 리턴하는 상태가 (8, 8, 1)의 HWC 이미지 텐서이므로 이를 (3, 15, 15)의 CHW 이미지로 변환
# - One-hot 인코딩도 필요

# %%
# Function to preprocess the state
# note that player 1 = env player, player 2 = agent
def preprocess_state(env_observ):
    st = torch.from_numpy(env_observ).squeeze()
    st = st.to(torch.int64)
    st = torch.nn.functional.one_hot(st,num_classes=3)
    st = st.permute(2, 0, 1)
    return st.to(torch.float32)

# %% [markdown]
# ### Epsilon-greedy 액션 선택 함수
#
# 학습시 에피소드 생성하면서 사용 (주의: 입력은 batch axis 없음)

# %%
# Function to select an action
# model: the torch model to compuate action-state value (i.e., q-value)
# state: a torch tensor (3 x 8 x 8) of float32, which is output by preprocess_state
# mask: a 64-size array (np.array)
def get_greedy_epsilon(model, state, mask):
    global epsilon

    #if frame_count < epsilon_random_frames or np.random.rand(1)[0] < epsilon:
    if np.random.rand(1)[0] < epsilon:
        action = np.random.choice([ i for i in range(num_actions) if mask[i] == 1 ])
    else:
        with torch.no_grad():
            # add a batch axis
            state_tensor = state.unsqueeze(0)
            # compute the q-values
            q_values = model(state_tensor)
            # select the q-values of valid actions
            action = torch.argmax(
                q_values.to('cpu').squeeze() + torch.from_numpy(mask) * 100., # trick to select a valid action
                dim=0)


            #valid_q = [ (i, q_values[0][i]) for i in range(64) if mask[i] == 1 ]
            # the action of maximum q-value
            #action, _ = max(valid_q, key=lambda e: e[1])

    # decay epsilon
    epsilon -= epsilon_interval / epsilon_greedy_frames
    epsilon = max(epsilon, epsilon_min)

    return action

# %% [markdown]
# ### Greedy 액션 선택 함수
#
# 나중에 evaluation 시 사용

# %%
def get_greedy_action(model, state, mask):
    global epsilon

    with torch.no_grad():
        state_tensor = state.unsqueeze(0) # batch dimension
        q_values = model(state_tensor)

        action = torch.argmax(
                q_values.to('cpu').squeeze() + torch.from_numpy(mask) * 100., # trick to select a valid action
                dim=0)

    return action
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ### Update 파트
#
# - Replay buffer 에서 batch하나를 샘플링하고,
# - model을 update한다.

# %%
# sample a batch of _batch_size from replay buffers
# return numpy.ndarrays
def sample_batch(_batch_size):
    # Get indices of samples for replay buffers
    indices = np.random.choice(range(len(done_history)), size=_batch_size, replace=False)

    state_sample = np.array([state_history[i].squeeze(0).numpy() for i in indices])
    state_next_sample = np.array([state_next_history[i].squeeze(0).numpy() for i in indices])
    rewards_sample = np.array([rewards_history[i] for i in indices], dtype=np.float32)
    action_sample = np.array([action_history[i] for i in indices])

    # action mask is the mask for the valid actions at the '''next''' state
    action_mask_sample = np.array([action_mask_history[i] for i in indices])
    done_sample = np.array([float(done_history[i]) for i in indices])

    return state_sample, state_next_sample, rewards_sample, action_sample, action_mask_sample, done_sample

# %%
# Function to update the Q-network
def update_network():
    # sample a batch of ...
    state_sample, state_next_sample, rewards_sample, action_sample, action_mask_sample, done_sample = \
        sample_batch(batch_size)

    # Convert numpy arrays to PyTorch tensors
    state_sample = torch.tensor(state_sample, dtype=torch.float32).to(device)
    state_next_sample = torch.tensor(state_next_sample, dtype=torch.float32).to(device)
    action_sample = torch.tensor(action_sample, dtype=torch.int64).to(device)
    action_mask_sample = torch.tensor(action_mask_sample, dtype=torch.int64).to(device)
    rewards_sample = torch.tensor(rewards_sample, dtype=torch.float32).to(device)
    done_sample = torch.tensor(done_sample, dtype=torch.float32).to(device)

    # Compute the target Q-values for the states
    with torch.no_grad():
        future_rewards = model_target(state_next_sample)
        #future_rewards = future_rewards.cpu()

        # compute the q-value for the next state and the action maximizing the q-value
        # note: the action should be valid (i.e., mask is set to 1)
        max_q_values = torch.max(
            future_rewards + action_mask_sample * 100., # trick to select a valid action
            dim=1).values.detach() - 100.

        # compute the target q-value
        # if the step was final, max_q_values should not be added
        # we assume that the negative return of the opposite player is the return of next step
        # that is, G(t) = r(t+1) - g*r(t+2) + g^2*r(t+3) - g^3*r(t+4) + ...
        target_q_values = rewards_sample + gamma * max_q_values * (1. - done_sample)

    # It's forward propagation! Compute the Q-values for the taken actions
    q_values = model(state_sample)
    #q_values = q_values.cpu()
    q_values_action = q_values.gather(dim=1, index=action_sample.unsqueeze(1)).squeeze(1)

    # Compute the loss
    loss = loss_function(q_values_action, target_q_values)

    # Perform the optimization step
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

# %% [markdown]
# # Run DQN Tranining

# %%
for _ in range(max_episodes):
    state, info = env.reset()
    state = preprocess_state(state)
    action_mask = info['action_mask'].reshape((-1,))
    episode_reward = 0

    for timestep in range(1, max_steps_per_episode):
        frame_count += 1

        # Select an action
        #state_cuda = state.to(device)
        action = get_greedy_epsilon(model,
                      state.to(device),
                      action_mask)
        if action < 0:
            print(action_mask)

        # Take the selected action
        state_next, reward, done, info = env.step((action // 8, action % 8))
        state_next = preprocess_state(state_next)
        action_mask = info['action_mask'].reshape((-1,))

        episode_reward += reward

        # Store the transition in the replay buffer
        action_history.append(action)
        action_mask_history.append(action_mask)
        state_history.append(state)
        state_next_history.append(state_next)
        rewards_history.append(reward)
        done_history.append(done)

        state = state_next

        # Update every fourth frame and once batch size is over 32
        if frame_count % update_after_actions == 0 and len(done_history) > batch_size:
            update_network()

        if frame_count % update_target_network == 0:
            model_target.load_state_dict(model.state_dict())

        # Limit the state and reward history
        if len(rewards_history) > max_memory_length:
            del rewards_history[:1]
            del state_history[:1]
            del state_next_history[:1]
            del action_history[:1]
            del action_mask_history[:1]
            del done_history[:1]

        if done:
            break

    episode_count += 1
    episode_reward_history.append(episode_reward)

    # Update running reward to check condition for solving
    if len(episode_reward_history) > 100:
        del episode_reward_history[:1]
    running_reward = np.mean(episode_reward_history)

    if episode_count % 10 == 0:
        print(f"Episode: {episode_count}, Frame count: {frame_count}, Running reward: {running_reward}")

    if episode_count % 5000 == 0:
        torch.save(model, 'model.{}'.format(episode_count))
    #if running_reward > 20:
    #    print(f"Solved at episode {episode_count}!")
    #    break


torch.save(model, 'model.final')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Episode: 20, Frame count: 1261, Running reward: -39.25
# Episode: 30, Frame count: 1838, Running reward: -38.93333333333333
# Episode: 40, Frame count: 2423, Running reward: -39.225
# Episode: 50, Frame count: 2964, Running reward: -38.48
# Episode: 60, Frame count: 3545, Running reward: -38.61666666666667
# Episode: 70, Frame count: 4133, Running reward: -38.871428571428574
# Episode: 80, Frame count: 4711, Running reward: -38.9625
# Episode: 90, Frame count: 5284, Running reward: -38.91111111111111
# Episode: 100, Frame count: 5855, Running reward: -38.91
# Episode: 110, Frame count: 6424, Running reward: -38.74
# Episode: 120, Frame count: 7005, Running reward: -38.98
# Episode: 130, Frame count: 7575, Running reward: -38.97
# Episode: 140, Frame count: 8119, Running reward: -38.46
# Episode: 150, Frame count: 8670, Running reward: -38.58
# Episode: 160, Frame count: 9238, Running reward: -38.43
# Episode: 170, Frame count: 9774, Running reward: -37.79
# Episode: 180, Frame count: 10321, Running reward: -37.38
# Episode: 190, Frame count: 10853, Running reward: -36.91
# Episode: 200, Frame count: 11420, Running reward: -36.79
# Episode: 210, Frame count: 11989, Running reward: -36.75
# Episode: 220, Frame count: 12537, Running reward: -36.24
# Episode: 230, Frame count: 13026, Running reward: -35.37
# Episode: 240, Frame count: 13595, Running reward: -35.72
# Episode: 250, Frame count: 14146, Running reward: -35.62
# Episode: 260, Frame count: 14699, Running reward: -35.45
# Episode: 270, Frame count: 15240, Running reward: -35.56
# Episode: 280, Frame count: 15790, Running reward: -35.59
# Episode: 290, Frame count: 16324, Running reward: -35.57
# Episode: 300, Frame count: 16884, Running reward: -35.5
# Episode: 310, Frame count: 17368, Running reward: -34.55
# Episode: 320, Frame count: 17877, Running reward: -34.16
# Episode: 330, Frame count: 18419, Running reward: -34.67
# Episode: 340, Frame count: 18947, Running reward: -34.16
# Episode: 350, Frame count: 19471, Running reward: -33.91
# Episode: 360, Frame count: 19968, Running reward: -33.29
# Episode: 370, Frame count: 20511, Running reward: -33.23
# Episode: 380, Frame count: 20995, Running reward: -32.51
# Episode: 390, Frame count: 21529, Running reward: -32.53
# Episode: 400, Frame count: 22060, Running reward: -32.18
# Episode: 410, Frame count: 22577, Running reward: -32.53
# Episode: 420, Frame count: 23099, Running reward: -32.7
# Episode: 430, Frame count: 23616, Running reward: -32.49
# Episode: 440, Frame count: 24137, Running reward: -32.44
# Episode: 450, Frame count: 24662, Running reward: -32.45
# Episode: 460, Frame count: 25150, Running reward: -32.38
# Episode: 470, Frame count: 25668, Running reward: -32.15
# Episode: 480, Frame count: 26162, Running reward: -32.27
# Episode: 490, Frame count: 26672, Running reward: -32.05
# Episode: 500, Frame count: 27233, Running reward: -32.41
# Episode: 510, Frame count: 27691, Running reward: -31.78
# Episode: 520, Frame count: 28162, Running reward: -31.17
# Episode: 530, Frame count: 28643, Running reward: -30.75
# Episode: 540, Frame count: 29181, Running reward: -30.86
# Episode: 550, Frame count: 29635, Running reward: -30.07
# Episode: 560, Frame count: 30109, Running reward: -29.91
# Episode: 570, Frame count: 30556, Running reward: -29.16
# Episode: 580, Frame count: 31082, Running reward: -29.48
# Episode: 590, Frame count: 31562, Running reward: -29.12
# Episode: 600, Frame count: 32048, Running reward: -28.27
# Episode: 610, Frame count: 32540, Running reward: -28.65
# Episode: 620, Frame count: 32962, Running reward: -28.14
# Episode: 630, Frame count: 33445, Running reward: -28.14
# Episode: 640, Frame count: 33895, Running reward: -27.24
# Episode: 650, Frame count: 34340, Running reward: -27.17
# Episode: 660, Frame count: 34764, Running reward: -26.65
# Episode: 670, Frame count: 35238, Running reward: -26.92
# Episode: 680, Frame count: 35670, Running reward: -25.94
# Episode: 690, Frame count: 36166, Running reward: -26.14
# Episode: 700, Frame count: 36605, Running reward: -25.67
# Episode: 710, Frame count: 37060, Running reward: -25.26
# Episode: 720, Frame count: 37496, Running reward: -25.42
# Episode: 730, Frame count: 37929, Running reward: -24.94
# Episode: 740, Frame count: 38390, Running reward: -25.05
# Episode: 750, Frame count: 38842, Running reward: -25.12
# Episode: 760, Frame count: 39289, Running reward: -25.35
# Episode: 770, Frame count: 39751, Running reward: -25.23
# Episode: 780, Frame count: 40186, Running reward: -25.26
# Episode: 790, Frame count: 40641, Running reward: -24.81
# Episode: 800, Frame count: 41099, Running reward: -25.02
# Episode: 810, Frame count: 41537, Running reward: -24.85
# Episode: 820, Frame count: 41976, Running reward: -24.86
# Episode: 830, Frame count: 42417, Running reward: -24.92
# Episode: 840, Frame count: 42881, Running reward: -24.95
# Episode: 850, Frame count: 43354, Running reward: -25.14
# Episode: 860, Frame count: 43769, Running reward: -24.84
# Episode: 870, Frame count: 44249, Running reward: -25.02
# Episode: 880, Frame count: 44681, Running reward: -24.99
# Episode: 890, Frame count: 45131, Running reward: -24.96
# Episode: 900, Frame count: 45557, Running reward: -24.62
# Episode: 910, Frame count: 45976, Running reward: -24.43
# Episode: 920, Frame count: 46410, Running reward: -24.38
# Episode: 930, Frame count: 46837, Running reward: -24.26
# Episode: 940, Frame count: 47301, Running reward: -24.28
# Episode: 950, Frame count: 47708, Running reward: -23.64
# Episode: 960, Frame count: 48158, Running reward: -23.97
# Episode: 970, Frame count: 48611, Running reward: -23.72
# Episode: 980, Frame count: 48977, Running reward: -23.06
# Episode: 990, Frame count: 49404, Running reward: -22.83
# Episode: 1000, Frame count: 49790, Running reward: -22.43
# Episode: 1010, Frame count: 50168, Running reward: -22.02
# Episode: 1020, Frame count: 50579, Running reward: -21.79
# Episode: 1030, Frame count: 51030, Running reward: -22.03
# Episode: 1040, Frame count: 51473, Running reward: -21.8
# Episode: 1050, Frame count: 51867, Running reward: -21.65
# Episode: 1060, Frame count: 52318, Running reward: -21.68
# Episode: 1070, Frame count: 52773, Running reward: -21.68
# Episode: 1080, Frame count: 53200, Running reward: -22.29
# Episode: 1090, Frame count: 53598, Running reward: -21.98
# Episode: 1100, Frame count: 54042, Running reward: -22.56
# Episode: 1110, Frame count: 54475, Running reward: -23.13
# Episode: 1120, Frame count: 54862, Running reward: -22.89
# Episode: 1130, Frame count: 55265, Running reward: -22.39
# Episode: 1140, Frame count: 55723, Running reward: -22.54
# Episode: 1150, Frame count: 56144, Running reward: -22.85
# Episode: 1160, Frame count: 56561, Running reward: -22.49
# Episode: 1170, Frame count: 56970, Running reward: -22.05
# Episode: 1180, Frame count: 57349, Running reward: -21.57
# Episode: 1190, Frame count: 57749, Running reward: -21.59
# Episode: 1200, Frame count: 58125, Running reward: -20.91
# Episode: 1210, Frame count: 58539, Running reward: -20.7
# Episode: 1220, Frame count: 58856, Running reward: -20.0
# Episode: 1230, Frame count: 59201, Running reward: -19.42
# Episode: 1240, Frame count: 59581, Running reward: -18.64
# Episode: 1250, Frame count: 59983, Running reward: -18.41
# Episode: 1260, Frame count: 60389, Running reward: -18.32
# Episode: 1270, Frame count: 60771, Running reward: -18.03
# Episode: 1280, Frame count: 61125, Running reward: -17.8
# Episode: 1290, Frame count: 61509, Running reward: -17.64
# Episode: 1300, Frame count: 61898, Running reward: -17.77
# Episode: 1310, Frame count: 62313, Running reward: -17.78
# Episode: 1320, Frame count: 62665, Running reward: -18.13
# Episode: 1330, Frame count: 63073, Running reward: -18.76
# Episode: 1340, Frame count: 63436, Running reward: -18.59
# Episode: 1350, Frame count: 63801, Running reward: -18.22
# Episode: 1360, Frame count: 64180, Running reward: -17.95
# Episode: 1370, Frame count: 64571, Running reward: -18.04
# Episode: 1380, Frame count: 64921, Running reward: -17.98
# Episode: 1390, Frame count: 65298, Running reward: -17.91
# Episode: 1400, Frame count: 65654, Running reward: -17.58
# Episode: 1410, Frame count: 66079, Running reward: -17.68
# Episode: 1420, Frame count: 66444, Running reward: -17.81
# Episode: 1430, Frame count: 66802, Running reward: -17.31
# Episode: 1440, Frame count: 67198, Running reward: -17.64
# Episode: 1450, Frame count: 67555, Running reward: -17.56
# Episode: 1460, Frame count: 67925, Running reward: -17.45
# Episode: 1470, Frame count: 68281, Running reward: -17.1
# Episode: 1480, Frame count: 68690, Running reward: -17.69
# Episode: 1490, Frame count: 69083, Running reward: -17.85
# Episode: 1500, Frame count: 69424, Running reward: -17.7
# Episode: 1510, Frame count: 69822, Running reward: -17.43
# Episode: 1520, Frame count: 70205, Running reward: -17.61
# Episode: 1530, Frame count: 70614, Running reward: -18.12
# Episode: 1540, Frame count: 71008, Running reward: -18.1
# Episode: 1550, Frame count: 71396, Running reward: -18.41
# Episode: 1560, Frame count: 71744, Running reward: -18.19
# Episode: 1570, Frame count: 72074, Running reward: -17.93
# Episode: 1580, Frame count: 72405, Running reward: -17.15
# Episode: 1590, Frame count: 72780, Running reward: -16.97
# Episode: 1600, Frame count: 73103, Running reward: -16.79
# Episode: 1610, Frame count: 73476, Running reward: -16.54
# Episode: 1620, Frame count: 73821, Running reward: -16.16
# Episode: 1630, Frame count: 74272, Running reward: -16.6
# Episode: 1640, Frame count: 74646, Running reward: -16.4
# Episode: 1650, Frame count: 75046, Running reward: -16.52
# Episode: 1660, Frame count: 75352, Running reward: -16.1
# Episode: 1670, Frame count: 75732, Running reward: -16.6
# Episode: 1680, Frame count: 76065, Running reward: -16.62
# Episode: 1690, Frame count: 76410, Running reward: -16.32
# Episode: 1700, Frame count: 76770, Running reward: -16.69
# Episode: 1710, Frame count: 77075, Running reward: -16.01
# Episode: 1720, Frame count: 77366, Running reward: -15.47
# Episode: 1730, Frame count: 77701, Running reward: -14.29
# Episode: 1740, Frame count: 78032, Running reward: -13.86
# Episode: 1750, Frame count: 78349, Running reward: -13.03
# Episode: 1760, Frame count: 78683, Running reward: -13.31
# Episode: 1770, Frame count: 78995, Running reward: -12.63
# Episode: 1780, Frame count: 79328, Running reward: -12.63
# Episode: 1790, Frame count: 79660, Running reward: -12.5
# Episode: 1800, Frame count: 80001, Running reward: -12.31
# Episode: 1810, Frame count: 80292, Running reward: -12.17
# Episode: 1820, Frame count: 80621, Running reward: -12.55
# Episode: 1830, Frame count: 80955, Running reward: -12.54
# Episode: 1840, Frame count: 81290, Running reward: -12.58
# Episode: 1850, Frame count: 81636, Running reward: -12.87
# Episode: 1860, Frame count: 82025, Running reward: -13.42
# Episode: 1870, Frame count: 82335, Running reward: -13.4
# Episode: 1880, Frame count: 82719, Running reward: -13.91
# Episode: 1890, Frame count: 83033, Running reward: -13.73
# Episode: 1900, Frame count: 83382, Running reward: -13.81
# Episode: 1910, Frame count: 83697, Running reward: -14.05
# Episode: 1920, Frame count: 84027, Running reward: -14.06
# Episode: 1930, Frame count: 84367, Running reward: -14.12
# Episode: 1940, Frame count: 84706, Running reward: -14.16
# Episode: 1950, Frame count: 85051, Running reward: -14.15
# Episode: 1960, Frame count: 85393, Running reward: -13.68
# Episode: 1970, Frame count: 85725, Running reward: -13.9
# Episode: 1980, Frame count: 86062, Running reward: -13.43
# Episode: 1990, Frame count: 86363, Running reward: -13.3
# Episode: 2000, Frame count: 86679, Running reward: -12.97
# Episode: 2010, Frame count: 87027, Running reward: -13.3
# Episode: 2020, Frame count: 87380, Running reward: -13.53
# Episode: 2030, Frame count: 87723, Running reward: -13.56
# Episode: 2040, Frame count: 88056, Running reward: -13.5
# Episode: 2050, Frame count: 88365, Running reward: -13.14
# Episode: 2060, Frame count: 88711, Running reward: -13.18
# Episode: 2070, Frame count: 89073, Running reward: -13.48
# Episode: 2080, Frame count: 89393, Running reward: -13.31
# Episode: 2090, Frame count: 89711, Running reward: -13.48
# Episode: 2100, Frame count: 90028, Running reward: -13.49
# Episode: 2110, Frame count: 90294, Running reward: -12.67
# Episode: 2120, Frame count: 90549, Running reward: -11.69
# Episode: 2130, Frame count: 90852, Running reward: -11.29
# Episode: 2140, Frame count: 91184, Running reward: -11.28
# Episode: 2150, Frame count: 91470, Running reward: -11.05
# Episode: 2160, Frame count: 91789, Running reward: -10.78
# Episode: 2170, Frame count: 92093, Running reward: -10.2
# Episode: 2180, Frame count: 92447, Running reward: -10.54
# Episode: 2190, Frame count: 92769, Running reward: -10.58
# Episode: 2200, Frame count: 93063, Running reward: -10.35
# Episode: 2210, Frame count: 93360, Running reward: -10.66
# Episode: 2220, Frame count: 93680, Running reward: -11.31
# Episode: 2230, Frame count: 93981, Running reward: -11.29
# Episode: 2240, Frame count: 94265, Running reward: -10.81
# Episode: 2250, Frame count: 94586, Running reward: -11.16
# Episode: 2260, Frame count: 94851, Running reward: -10.62
# Episode: 2270, Frame count: 95160, Running reward: -10.67
# Episode: 2280, Frame count: 95439, Running reward: -9.92
# Episode: 2290, Frame count: 95756, Running reward: -9.87
# Episode: 2300, Frame count: 96051, Running reward: -9.88
# Episode: 2310, Frame count: 96345, Running reward: -9.85
# Episode: 2320, Frame count: 96651, Running reward: -9.71
# Episode: 2330, Frame count: 96991, Running reward: -10.1
# Episode: 2340, Frame count: 97300, Running reward: -10.35
# Episode: 2350, Frame count: 97595, Running reward: -10.09
# Episode: 2360, Frame count: 97902, Running reward: -10.51
# Episode: 2370, Frame count: 98183, Running reward: -10.23
# Episode: 2380, Frame count: 98474, Running reward: -10.35
# Episode: 2390, Frame count: 98744, Running reward: -9.88
# Episode: 2400, Frame count: 99035, Running reward: -9.84
# Episode: 2410, Frame count: 99297, Running reward: -9.52
# Episode: 2420, Frame count: 99612, Running reward: -9.61
# Episode: 2430, Frame count: 99909, Running reward: -9.18
# Episode: 2440, Frame count: 100174, Running reward: -8.74
# Episode: 2450, Frame count: 100466, Running reward: -8.71
# Episode: 2460, Frame count: 100757, Running reward: -8.55
# Episode: 2470, Frame count: 101045, Running reward: -8.62
# Episode: 2480, Frame count: 101334, Running reward: -8.6
# Episode: 2490, Frame count: 101612, Running reward: -8.68
# Episode: 2500, Frame count: 101945, Running reward: -9.1
# Episode: 2510, Frame count: 102250, Running reward: -9.53
# Episode: 2520, Frame count: 102563, Running reward: -9.51
# Episode: 2530, Frame count: 102839, Running reward: -9.3
# Episode: 2540, Frame count: 103120, Running reward: -9.46
# Episode: 2550, Frame count: 103398, Running reward: -9.32
# Episode: 2560, Frame count: 103715, Running reward: -9.58
# Episode: 2570, Frame count: 103983, Running reward: -9.38
# Episode: 2580, Frame count: 104245, Running reward: -9.11
# Episode: 2590, Frame count: 104528, Running reward: -9.16
# Episode: 2600, Frame count: 104853, Running reward: -9.08
# Episode: 2610, Frame count: 105133, Running reward: -8.83
# Episode: 2620, Frame count: 105395, Running reward: -8.32
# Episode: 2630, Frame count: 105653, Running reward: -8.14
# Episode: 2640, Frame count: 105934, Running reward: -8.14
# Episode: 2650, Frame count: 106231, Running reward: -8.33
# Episode: 2660, Frame count: 106532, Running reward: -8.17
# Episode: 2670, Frame count: 106819, Running reward: -8.36
# Episode: 2680, Frame count: 107111, Running reward: -8.66
# Episode: 2690, Frame count: 107390, Running reward: -8.62
# Episode: 2700, Frame count: 107689, Running reward: -8.36
# Episode: 2710, Frame count: 107946, Running reward: -8.13
# Episode: 2720, Frame count: 108223, Running reward: -8.28
# Episode: 2730, Frame count: 108527, Running reward: -8.74
# Episode: 2740, Frame count: 108826, Running reward: -8.92
# Episode: 2750, Frame count: 109119, Running reward: -8.88
# Episode: 2760, Frame count: 109358, Running reward: -8.26
# Episode: 2770, Frame count: 109628, Running reward: -8.09
# Episode: 2780, Frame count: 109941, Running reward: -8.3
# Episode: 2790, Frame count: 110224, Running reward: -8.34
# Episode: 2800, Frame count: 110497, Running reward: -8.08
# Episode: 2810, Frame count: 110780, Running reward: -8.34
# Episode: 2820, Frame count: 111011, Running reward: -7.88
# Episode: 2830, Frame count: 111293, Running reward: -7.66
# Episode: 2840, Frame count: 111610, Running reward: -7.84
# Episode: 2850, Frame count: 111900, Running reward: -7.81
# Episode: 2860, Frame count: 112182, Running reward: -8.24
# Episode: 2870, Frame count: 112462, Running reward: -8.34
# Episode: 2880, Frame count: 112796, Running reward: -8.55
# Episode: 2890, Frame count: 113104, Running reward: -8.8
# Episode: 2900, Frame count: 113379, Running reward: -8.82
# Episode: 2910, Frame count: 113626, Running reward: -8.46
# Episode: 2920, Frame count: 113890, Running reward: -8.79
# Episode: 2930, Frame count: 114162, Running reward: -8.69
# Episode: 2940, Frame count: 114436, Running reward: -8.26
# Episode: 2950, Frame count: 114732, Running reward: -8.32
# Episode: 2960, Frame count: 115032, Running reward: -8.5
# Episode: 2970, Frame count: 115284, Running reward: -8.22
# Episode: 2980, Frame count: 115549, Running reward: -7.53
# Episode: 2990, Frame count: 115829, Running reward: -7.25
# Episode: 3000, Frame count: 116102, Running reward: -7.23
# Episode: 3010, Frame count: 116349, Running reward: -7.23
# Episode: 3020, Frame count: 116630, Running reward: -7.4
# Episode: 3030, Frame count: 116871, Running reward: -7.09
# Episode: 3040, Frame count: 117140, Running reward: -7.04
# Episode: 3050, Frame count: 117426, Running reward: -6.94
# Episode: 3060, Frame count: 117711, Running reward: -6.79
# Episode: 3070, Frame count: 118023, Running reward: -7.39
# Episode: 3080, Frame count: 118313, Running reward: -7.64
# Episode: 3090, Frame count: 118609, Running reward: -7.8
# Episode: 3100, Frame count: 118811, Running reward: -7.09
# Episode: 3110, Frame count: 119063, Running reward: -7.14
# Episode: 3120, Frame count: 119318, Running reward: -6.88
# Episode: 3130, Frame count: 119589, Running reward: -7.18
# Episode: 3140, Frame count: 119855, Running reward: -7.15
# Episode: 3150, Frame count: 120103, Running reward: -6.77
# Episode: 3160, Frame count: 120367, Running reward: -6.56
# Episode: 3170, Frame count: 120616, Running reward: -5.93
# Episode: 3180, Frame count: 120861, Running reward: -5.48
# Episode: 3190, Frame count: 121145, Running reward: -5.36
# Episode: 3200, Frame count: 121439, Running reward: -6.28
# Episode: 3210, Frame count: 121692, Running reward: -6.29
# Episode: 3220, Frame count: 121940, Running reward: -6.22
# Episode: 3230, Frame count: 122183, Running reward: -5.94
# Episode: 3240, Frame count: 122452, Running reward: -5.97
# Episode: 3250, Frame count: 122669, Running reward: -5.66
# Episode: 3260, Frame count: 122921, Running reward: -5.54
# Episode: 3270, Frame count: 123185, Running reward: -5.69
# Episode: 3280, Frame count: 123449, Running reward: -5.88
# Episode: 3290, Frame count: 123709, Running reward: -5.64
# Episode: 3300, Frame count: 123952, Running reward: -5.13
# Episode: 3310, Frame count: 124230, Running reward: -5.38
# Episode: 3320, Frame count: 124523, Running reward: -5.83
# Episode: 3330, Frame count: 124780, Running reward: -5.97
# Episode: 3340, Frame count: 125022, Running reward: -5.7
# Episode: 3350, Frame count: 125248, Running reward: -5.79
# Episode: 3360, Frame count: 125516, Running reward: -5.95
# Episode: 3370, Frame count: 125759, Running reward: -5.74
# Episode: 3380, Frame count: 126016, Running reward: -5.67
# Episode: 3390, Frame count: 126284, Running reward: -5.75
# Episode: 3400, Frame count: 126532, Running reward: -5.8
# Episode: 3410, Frame count: 126785, Running reward: -5.55
# Episode: 3420, Frame count: 127070, Running reward: -5.47
# Episode: 3430, Frame count: 127315, Running reward: -5.35
# Episode: 3440, Frame count: 127571, Running reward: -5.49
# Episode: 3450, Frame count: 127794, Running reward: -5.46
# Episode: 3460, Frame count: 128065, Running reward: -5.49
# Episode: 3470, Frame count: 128324, Running reward: -5.65
# Episode: 3480, Frame count: 128549, Running reward: -5.33
# Episode: 3490, Frame count: 128781, Running reward: -4.97
# Episode: 3500, Frame count: 129039, Running reward: -5.07
# Episode: 3510, Frame count: 129259, Running reward: -4.74
# Episode: 3520, Frame count: 129508, Running reward: -4.38
# Episode: 3530, Frame count: 129761, Running reward: -4.46
# Episode: 3540, Frame count: 130022, Running reward: -4.51
# Episode: 3550, Frame count: 130255, Running reward: -4.61
# Episode: 3560, Frame count: 130498, Running reward: -4.33
# Episode: 3570, Frame count: 130768, Running reward: -4.44
# Episode: 3580, Frame count: 130978, Running reward: -4.29
# Episode: 3590, Frame count: 131219, Running reward: -4.38
# Episode: 3600, Frame count: 131461, Running reward: -4.22
# Episode: 3610, Frame count: 131701, Running reward: -4.42
# Episode: 3620, Frame count: 131948, Running reward: -4.4
# Episode: 3630, Frame count: 132179, Running reward: -4.18
# Episode: 3640, Frame count: 132408, Running reward: -3.86
# Episode: 3650, Frame count: 132646, Running reward: -3.91
# Episode: 3660, Frame count: 132902, Running reward: -4.04
# Episode: 3670, Frame count: 133139, Running reward: -3.71
# Episode: 3680, Frame count: 133370, Running reward: -3.92
# Episode: 3690, Frame count: 133621, Running reward: -4.02
# Episode: 3700, Frame count: 133853, Running reward: -3.92
# Episode: 3710, Frame count: 134100, Running reward: -3.99
# Episode: 3720, Frame count: 134324, Running reward: -3.76
# Episode: 3730, Frame count: 134561, Running reward: -3.82
# Episode: 3740, Frame count: 134786, Running reward: -3.78
# Episode: 3750, Frame count: 135023, Running reward: -3.77
# Episode: 3760, Frame count: 135264, Running reward: -3.62
# Episode: 3770, Frame count: 135502, Running reward: -3.63
# Episode: 3780, Frame count: 135756, Running reward: -3.86
# Episode: 3790, Frame count: 135991, Running reward: -3.7
# Episode: 3800, Frame count: 136228, Running reward: -3.75
# Episode: 3810, Frame count: 136471, Running reward: -3.71
# Episode: 3820, Frame count: 136704, Running reward: -3.8
# Episode: 3830, Frame count: 136929, Running reward: -3.68
# Episode: 3840, Frame count: 137156, Running reward: -3.7
# Episode: 3850, Frame count: 137424, Running reward: -4.01
# Episode: 3860, Frame count: 137661, Running reward: -3.97
# Episode: 3870, Frame count: 137898, Running reward: -3.96
# Episode: 3880, Frame count: 138129, Running reward: -3.73
# Episode: 3890, Frame count: 138346, Running reward: -3.55
# Episode: 3900, Frame count: 138578, Running reward: -3.5
# Episode: 3910, Frame count: 138820, Running reward: -3.49
# Episode: 3920, Frame count: 139040, Running reward: -3.36
# Episode: 3930, Frame count: 139245, Running reward: -3.16
# Episode: 3940, Frame count: 139454, Running reward: -2.98
# Episode: 3950, Frame count: 139689, Running reward: -2.65
# Episode: 3960, Frame count: 139951, Running reward: -2.9
# Episode: 3970, Frame count: 140156, Running reward: -2.58
# Episode: 3980, Frame count: 140394, Running reward: -2.65
# Episode: 3990, Frame count: 140632, Running reward: -2.86
# Episode: 4000, Frame count: 140851, Running reward: -2.73
# Episode: 4010, Frame count: 141069, Running reward: -2.49
# Episode: 4020, Frame count: 141266, Running reward: -2.26
# Episode: 4030, Frame count: 141481, Running reward: -2.36
# Episode: 4040, Frame count: 141726, Running reward: -2.72
# Episode: 4050, Frame count: 141939, Running reward: -2.5
# Episode: 4060, Frame count: 142187, Running reward: -2.36
# Episode: 4070, Frame count: 142427, Running reward: -2.71
# Episode: 4080, Frame count: 142662, Running reward: -2.68
# Episode: 4090, Frame count: 142901, Running reward: -2.69
# Episode: 4100, Frame count: 143147, Running reward: -2.96
# Episode: 4110, Frame count: 143382, Running reward: -3.13
# Episode: 4120, Frame count: 143622, Running reward: -3.56
# Episode: 4130, Frame count: 143842, Running reward: -3.61
# Episode: 4140, Frame count: 144069, Running reward: -3.43
# Episode: 4150, Frame count: 144290, Running reward: -3.51
# Episode: 4160, Frame count: 144512, Running reward: -3.25
# Episode: 4170, Frame count: 144746, Running reward: -3.19
# Episode: 4180, Frame count: 144956, Running reward: -2.94
# Episode: 4190, Frame count: 145188, Running reward: -2.87
# Episode: 4200, Frame count: 145413, Running reward: -2.66
# Episode: 4210, Frame count: 145630, Running reward: -2.48
# Episode: 4220, Frame count: 145844, Running reward: -2.22
# Episode: 4230, Frame count: 146076, Running reward: -2.34
# Episode: 4240, Frame count: 146280, Running reward: -2.11
# Episode: 4250, Frame count: 146518, Running reward: -2.28
# Episode: 4260, Frame count: 146750, Running reward: -2.38
# Episode: 4270, Frame count: 146947, Running reward: -2.01
# Episode: 4280, Frame count: 147172, Running reward: -2.16
# Episode: 4290, Frame count: 147402, Running reward: -2.14
# Episode: 4300, Frame count: 147643, Running reward: -2.3
# Episode: 4310, Frame count: 147861, Running reward: -2.31
# Episode: 4320, Frame count: 148085, Running reward: -2.41
# Episode: 4330, Frame count: 148314, Running reward: -2.38
# Episode: 4340, Frame count: 148554, Running reward: -2.74
# Episode: 4350, Frame count: 148755, Running reward: -2.37
# Episode: 4360, Frame count: 148970, Running reward: -2.2
# Episode: 4370, Frame count: 149177, Running reward: -2.3
# Episode: 4380, Frame count: 149414, Running reward: -2.42
# Episode: 4390, Frame count: 149627, Running reward: -2.25
# Episode: 4400, Frame count: 149833, Running reward: -1.9
# Episode: 4410, Frame count: 150034, Running reward: -1.73
# Episode: 4420, Frame count: 150241, Running reward: -1.56
# Episode: 4430, Frame count: 150445, Running reward: -1.31
# Episode: 4440, Frame count: 150686, Running reward: -1.32
# Episode: 4450, Frame count: 150886, Running reward: -1.31
# Episode: 4460, Frame count: 151089, Running reward: -1.19
# Episode: 4470, Frame count: 151310, Running reward: -1.33
# Episode: 4480, Frame count: 151533, Running reward: -1.19
# Episode: 4490, Frame count: 151733, Running reward: -1.06
# Episode: 4500, Frame count: 151962, Running reward: -1.29
# Episode: 4510, Frame count: 152207, Running reward: -1.73
# Episode: 4520, Frame count: 152425, Running reward: -1.84
# Episode: 4530, Frame count: 152627, Running reward: -1.82
# Episode: 4540, Frame count: 152862, Running reward: -1.76
# Episode: 4550, Frame count: 153059, Running reward: -1.73
# Episode: 4560, Frame count: 153258, Running reward: -1.69
# Episode: 4570, Frame count: 153490, Running reward: -1.8
# Episode: 4580, Frame count: 153671, Running reward: -1.38
# Episode: 4590, Frame count: 153878, Running reward: -1.45
# Episode: 4600, Frame count: 154075, Running reward: -1.13
# Episode: 4610, Frame count: 154277, Running reward: -0.7
# Episode: 4620, Frame count: 154482, Running reward: -0.57
# Episode: 4630, Frame count: 154689, Running reward: -0.62
# Episode: 4640, Frame count: 154891, Running reward: -0.29
# Episode: 4650, Frame count: 155114, Running reward: -0.55
# Episode: 4660, Frame count: 155320, Running reward: -0.62
# Episode: 4670, Frame count: 155544, Running reward: -0.54
# Episode: 4680, Frame count: 155761, Running reward: -0.9
# Episode: 4690, Frame count: 155968, Running reward: -0.9
# Episode: 4700, Frame count: 156193, Running reward: -1.18
# Episode: 4710, Frame count: 156400, Running reward: -1.23
# Episode: 4720, Frame count: 156626, Running reward: -1.44
# Episode: 4730, Frame count: 156812, Running reward: -1.23
# Episode: 4740, Frame count: 156997, Running reward: -1.06
# Episode: 4750, Frame count: 157211, Running reward: -0.97
# Episode: 4760, Frame count: 157409, Running reward: -0.89
# Episode: 4770, Frame count: 157630, Running reward: -0.86
# Episode: 4780, Frame count: 157848, Running reward: -0.87
# Episode: 4790, Frame count: 158042, Running reward: -0.74
# Episode: 4800, Frame count: 158248, Running reward: -0.55
# Episode: 4810, Frame count: 158467, Running reward: -0.67
# Episode: 4820, Frame count: 158673, Running reward: -0.47
# Episode: 4830, Frame count: 158883, Running reward: -0.71
# Episode: 4840, Frame count: 159102, Running reward: -1.05
# Episode: 4850, Frame count: 159295, Running reward: -0.84
# Episode: 4860, Frame count: 159538, Running reward: -1.29
# Episode: 4870, Frame count: 159737, Running reward: -1.07
# Episode: 4880, Frame count: 159955, Running reward: -1.07
# Episode: 4890, Frame count: 160178, Running reward: -1.36
# Episode: 4900, Frame count: 160377, Running reward: -1.29
# Episode: 4910, Frame count: 160588, Running reward: -1.21
# Episode: 4920, Frame count: 160787, Running reward: -1.14
# Episode: 4930, Frame count: 160987, Running reward: -1.04
# Episode: 4940, Frame count: 161204, Running reward: -1.02
# Episode: 4950, Frame count: 161393, Running reward: -0.98
# Episode: 4960, Frame count: 161601, Running reward: -0.63
# Episode: 4970, Frame count: 161812, Running reward: -0.75
# Episode: 4980, Frame count: 162005, Running reward: -0.5
# Episode: 4990, Frame count: 162201, Running reward: -0.23
# Episode: 5000, Frame count: 162432, Running reward: -0.55
# Episode: 5010, Frame count: 162622, Running reward: -0.34
# Episode: 5020, Frame count: 162812, Running reward: -0.25
# Episode: 5030, Frame count: 163018, Running reward: -0.31
# Episode: 5040, Frame count: 163205, Running reward: -0.01
# Episode: 5050, Frame count: 163384, Running reward: 0.09
# Episode: 5060, Frame count: 163610, Running reward: -0.09
# Episode: 5070, Frame count: 163807, Running reward: 0.05
# Episode: 5080, Frame count: 164007, Running reward: -0.02
# Episode: 5090, Frame count: 164235, Running reward: -0.34
# Episode: 5100, Frame count: 164466, Running reward: -0.34
# Episode: 5110, Frame count: 164656, Running reward: -0.34
# Episode: 5120, Frame count: 164871, Running reward: -0.59
# Episode: 5130, Frame count: 165078, Running reward: -0.6
# Episode: 5140, Frame count: 165286, Running reward: -0.81
# Episode: 5150, Frame count: 165480, Running reward: -0.96
# Episode: 5160, Frame count: 165697, Running reward: -0.87
# Episode: 5170, Frame count: 165885, Running reward: -0.78
# Episode: 5180, Frame count: 166066, Running reward: -0.59
# Episode: 5190, Frame count: 166268, Running reward: -0.33
# Episode: 5200, Frame count: 166474, Running reward: -0.08
# Episode: 5210, Frame count: 166681, Running reward: -0.25
# Episode: 5220, Frame count: 166886, Running reward: -0.15
# Episode: 5230, Frame count: 167104, Running reward: -0.26
# Episode: 5240, Frame count: 167304, Running reward: -0.18
# Episode: 5250, Frame count: 167517, Running reward: -0.37
# Episode: 5260, Frame count: 167697, Running reward: 0.0
# Episode: 5270, Frame count: 167900, Running reward: -0.15
# Episode: 5280, Frame count: 168082, Running reward: -0.16
# Episode: 5290, Frame count: 168261, Running reward: 0.07
# Episode: 5300, Frame count: 168466, Running reward: 0.08
# Episode: 5310, Frame count: 168672, Running reward: 0.09
# Episode: 5320, Frame count: 168860, Running reward: 0.26
# Episode: 5330, Frame count: 169050, Running reward: 0.54
# Episode: 5340, Frame count: 169243, Running reward: 0.61
# Episode: 5350, Frame count: 169441, Running reward: 0.76
# Episode: 5360, Frame count: 169627, Running reward: 0.7
# Episode: 5370, Frame count: 169833, Running reward: 0.67
# Episode: 5380, Frame count: 170022, Running reward: 0.6
# Episode: 5390, Frame count: 170218, Running reward: 0.43
# Episode: 5400, Frame count: 170397, Running reward: 0.69
# Episode: 5410, Frame count: 170577, Running reward: 0.95
# Episode: 5420, Frame count: 170773, Running reward: 0.87
# Episode: 5430, Frame count: 170957, Running reward: 0.93
# Episode: 5440, Frame count: 171132, Running reward: 1.11
# Episode: 5450, Frame count: 171323, Running reward: 1.18
# Episode: 5460, Frame count: 171490, Running reward: 1.37
# Episode: 5470, Frame count: 171691, Running reward: 1.42
# Episode: 5480, Frame count: 171866, Running reward: 1.56
# Episode: 5490, Frame count: 172056, Running reward: 1.62
# Episode: 5500, Frame count: 172257, Running reward: 1.4
# Episode: 5510, Frame count: 172437, Running reward: 1.4
# Episode: 5520, Frame count: 172623, Running reward: 1.5
# Episode: 5530, Frame count: 172811, Running reward: 1.46
# Episode: 5540, Frame count: 173007, Running reward: 1.25
# Episode: 5550, Frame count: 173204, Running reward: 1.19
# Episode: 5560, Frame count: 173422, Running reward: 0.68
# Episode: 5570, Frame count: 173620, Running reward: 0.71
# Episode: 5580, Frame count: 173839, Running reward: 0.27
# Episode: 5590, Frame count: 174023, Running reward: 0.33
# Episode: 5600, Frame count: 174230, Running reward: 0.27
# Episode: 5610, Frame count: 174413, Running reward: 0.24
# Episode: 5620, Frame count: 174602, Running reward: 0.21
# Episode: 5630, Frame count: 174778, Running reward: 0.33
# Episode: 5640, Frame count: 174966, Running reward: 0.41
# Episode: 5650, Frame count: 175139, Running reward: 0.65
# Episode: 5660, Frame count: 175328, Running reward: 0.94
# Episode: 5670, Frame count: 175509, Running reward: 1.11
# Episode: 5680, Frame count: 175714, Running reward: 1.25
# Episode: 5690, Frame count: 175888, Running reward: 1.35
# Episode: 5700, Frame count: 176078, Running reward: 1.52
# Episode: 5710, Frame count: 176271, Running reward: 1.42
# Episode: 5720, Frame count: 176437, Running reward: 1.65
# Episode: 5730, Frame count: 176609, Running reward: 1.69
# Episode: 5740, Frame count: 176769, Running reward: 1.97
# Episode: 5750, Frame count: 176932, Running reward: 2.07
# Episode: 5760, Frame count: 177104, Running reward: 2.24
# Episode: 5770, Frame count: 177283, Running reward: 2.26
# Episode: 5780, Frame count: 177470, Running reward: 2.44
# Episode: 5790, Frame count: 177665, Running reward: 2.23
# Episode: 5800, Frame count: 177869, Running reward: 2.09
# Episode: 5810, Frame count: 178045, Running reward: 2.26
# Episode: 5820, Frame count: 178222, Running reward: 2.15
# Episode: 5830, Frame count: 178413, Running reward: 1.96
# Episode: 5840, Frame count: 178597, Running reward: 1.72
# Episode: 5850, Frame count: 178766, Running reward: 1.66
# Episode: 5860, Frame count: 178939, Running reward: 1.65
# Episode: 5870, Frame count: 179140, Running reward: 1.43
# Episode: 5880, Frame count: 179318, Running reward: 1.52
# Episode: 5890, Frame count: 179498, Running reward: 1.67
# Episode: 5900, Frame count: 179673, Running reward: 1.96
# Episode: 5910, Frame count: 179854, Running reward: 1.91
# Episode: 5920, Frame count: 180040, Running reward: 1.82
# Episode: 5930, Frame count: 180230, Running reward: 1.83
# Episode: 5940, Frame count: 180432, Running reward: 1.65
# Episode: 5950, Frame count: 180611, Running reward: 1.55
# Episode: 5960, Frame count: 180799, Running reward: 1.4
# Episode: 5970, Frame count: 180992, Running reward: 1.48
# Episode: 5980, Frame count: 181188, Running reward: 1.3
# Episode: 5990, Frame count: 181374, Running reward: 1.24
# Episode: 6000, Frame count: 181562, Running reward: 1.11
# Episode: 6010, Frame count: 181727, Running reward: 1.27
# Episode: 6020, Frame count: 181908, Running reward: 1.32
# Episode: 6030, Frame count: 182082, Running reward: 1.48
# Episode: 6040, Frame count: 182249, Running reward: 1.83
# Episode: 6050, Frame count: 182431, Running reward: 1.8
# Episode: 6060, Frame count: 182627, Running reward: 1.72
# Episode: 6070, Frame count: 182803, Running reward: 1.89
# Episode: 6080, Frame count: 182977, Running reward: 2.11
# Episode: 6090, Frame count: 183145, Running reward: 2.29
# Episode: 6100, Frame count: 183309, Running reward: 2.53
# Episode: 6110, Frame count: 183494, Running reward: 2.33
# Episode: 6120, Frame count: 183683, Running reward: 2.25
# Episode: 6130, Frame count: 183863, Running reward: 2.19
# Episode: 6140, Frame count: 184042, Running reward: 2.07
# Episode: 6150, Frame count: 184212, Running reward: 2.19
# Episode: 6160, Frame count: 184398, Running reward: 2.29
# Episode: 6170, Frame count: 184571, Running reward: 2.32
# Episode: 6180, Frame count: 184739, Running reward: 2.38
# Episode: 6190, Frame count: 184900, Running reward: 2.45
# Episode: 6200, Frame count: 185092, Running reward: 2.17
# Episode: 6210, Frame count: 185275, Running reward: 2.19
# Episode: 6220, Frame count: 185445, Running reward: 2.38
# Episode: 6230, Frame count: 185639, Running reward: 2.24
# Episode: 6240, Frame count: 185804, Running reward: 2.38
# Episode: 6250, Frame count: 185969, Running reward: 2.43
# Episode: 6260, Frame count: 186136, Running reward: 2.62
# Episode: 6270, Frame count: 186315, Running reward: 2.56
# Episode: 6280, Frame count: 186486, Running reward: 2.53
# Episode: 6290, Frame count: 186651, Running reward: 2.49
# Episode: 6300, Frame count: 186827, Running reward: 2.65
# Episode: 6310, Frame count: 187018, Running reward: 2.57
# Episode: 6320, Frame count: 187185, Running reward: 2.6
# Episode: 6330, Frame count: 187368, Running reward: 2.71
# Episode: 6340, Frame count: 187553, Running reward: 2.51
# Episode: 6350, Frame count: 187728, Running reward: 2.41
# Episode: 6360, Frame count: 187903, Running reward: 2.33
# Episode: 6370, Frame count: 188068, Running reward: 2.47
# Episode: 6380, Frame count: 188251, Running reward: 2.35
# Episode: 6390, Frame count: 188417, Running reward: 2.34
# Episode: 6400, Frame count: 188603, Running reward: 2.24
# Episode: 6410, Frame count: 188764, Running reward: 2.54
# Episode: 6420, Frame count: 188930, Running reward: 2.55
# Episode: 6430, Frame count: 189095, Running reward: 2.73
# Episode: 6440, Frame count: 189267, Running reward: 2.86
# Episode: 6450, Frame count: 189442, Running reward: 2.86
# Episode: 6460, Frame count: 189629, Running reward: 2.74
# Episode: 6470, Frame count: 189812, Running reward: 2.56
# Episode: 6480, Frame count: 189977, Running reward: 2.74
# Episode: 6490, Frame count: 190143, Running reward: 2.74
# Episode: 6500, Frame count: 190313, Running reward: 2.9
# Episode: 6510, Frame count: 190486, Running reward: 2.78
# Episode: 6520, Frame count: 190685, Running reward: 2.45
# Episode: 6530, Frame count: 190864, Running reward: 2.31
# Episode: 6540, Frame count: 191025, Running reward: 2.42
# Episode: 6550, Frame count: 191186, Running reward: 2.56
# Episode: 6560, Frame count: 191357, Running reward: 2.72
# Episode: 6570, Frame count: 191545, Running reward: 2.67
# Episode: 6580, Frame count: 191724, Running reward: 2.53
# Episode: 6590, Frame count: 191900, Running reward: 2.43
# Episode: 6600, Frame count: 192078, Running reward: 2.35
# Episode: 6610, Frame count: 192242, Running reward: 2.44
# Episode: 6620, Frame count: 192424, Running reward: 2.61
# Episode: 6630, Frame count: 192598, Running reward: 2.66
# Episode: 6640, Frame count: 192773, Running reward: 2.52
# Episode: 6650, Frame count: 192945, Running reward: 2.41
# Episode: 6660, Frame count: 193110, Running reward: 2.47
# Episode: 6670, Frame count: 193288, Running reward: 2.57
# Episode: 6680, Frame count: 193459, Running reward: 2.65
# Episode: 6690, Frame count: 193633, Running reward: 2.67
# Episode: 6700, Frame count: 193824, Running reward: 2.54
# Episode: 6710, Frame count: 193986, Running reward: 2.56
# Episode: 6720, Frame count: 194156, Running reward: 2.68
# Episode: 6730, Frame count: 194343, Running reward: 2.55
# Episode: 6740, Frame count: 194513, Running reward: 2.6
# Episode: 6750, Frame count: 194669, Running reward: 2.76
# Episode: 6760, Frame count: 194837, Running reward: 2.73
# Episode: 6770, Frame count: 195014, Running reward: 2.74
# Episode: 6780, Frame count: 195171, Running reward: 2.88
# Episode: 6790, Frame count: 195343, Running reward: 2.9
# Episode: 6800, Frame count: 195505, Running reward: 3.19
# Episode: 6810, Frame count: 195662, Running reward: 3.24
# Episode: 6820, Frame count: 195814, Running reward: 3.42
# Episode: 6830, Frame count: 195983, Running reward: 3.6
# Episode: 6840, Frame count: 196156, Running reward: 3.57
# Episode: 6850, Frame count: 196344, Running reward: 3.25
# Episode: 6860, Frame count: 196503, Running reward: 3.34
# Episode: 6870, Frame count: 196664, Running reward: 3.5
# Episode: 6880, Frame count: 196828, Running reward: 3.43
# Episode: 6890, Frame count: 196995, Running reward: 3.48
# Episode: 6900, Frame count: 197163, Running reward: 3.42
# Episode: 6910, Frame count: 197329, Running reward: 3.33
# Episode: 6920, Frame count: 197498, Running reward: 3.16
# Episode: 6930, Frame count: 197684, Running reward: 2.99
# Episode: 6940, Frame count: 197866, Running reward: 2.9
# Episode: 6950, Frame count: 198025, Running reward: 3.19
# Episode: 6960, Frame count: 198186, Running reward: 3.17
# Episode: 6970, Frame count: 198339, Running reward: 3.25
# Episode: 6980, Frame count: 198500, Running reward: 3.28
# Episode: 6990, Frame count: 198653, Running reward: 3.42
# Episode: 7000, Frame count: 198822, Running reward: 3.41
# Episode: 7010, Frame count: 198999, Running reward: 3.3
# Episode: 7020, Frame count: 199154, Running reward: 3.44
# Episode: 7030, Frame count: 199319, Running reward: 3.65
# Episode: 7040, Frame count: 199469, Running reward: 3.97
# Episode: 7050, Frame count: 199625, Running reward: 4.0
# Episode: 7060, Frame count: 199787, Running reward: 3.99
# Episode: 7070, Frame count: 199953, Running reward: 3.86
# Episode: 7080, Frame count: 200132, Running reward: 3.68
# Episode: 7090, Frame count: 200300, Running reward: 3.53
# Episode: 7100, Frame count: 200455, Running reward: 3.67
# Episode: 7110, Frame count: 200624, Running reward: 3.75
# Episode: 7120, Frame count: 200795, Running reward: 3.59
# Episode: 7130, Frame count: 200955, Running reward: 3.64
# Episode: 7140, Frame count: 201117, Running reward: 3.52
# Episode: 7150, Frame count: 201293, Running reward: 3.32
# Episode: 7160, Frame count: 201450, Running reward: 3.37
# Episode: 7170, Frame count: 201604, Running reward: 3.49
# Episode: 7180, Frame count: 201764, Running reward: 3.68
# Episode: 7190, Frame count: 201923, Running reward: 3.77
# Episode: 7200, Frame count: 202086, Running reward: 3.69
# Episode: 7210, Frame count: 202255, Running reward: 3.69
# Episode: 7220, Frame count: 202432, Running reward: 3.63
# Episode: 7230, Frame count: 202605, Running reward: 3.5
# Episode: 7240, Frame count: 202766, Running reward: 3.51
# Episode: 7250, Frame count: 202909, Running reward: 3.84
# Episode: 7260, Frame count: 203073, Running reward: 3.77
# Episode: 7270, Frame count: 203239, Running reward: 3.65
# Episode: 7280, Frame count: 203413, Running reward: 3.51
# Episode: 7290, Frame count: 203577, Running reward: 3.46
# Episode: 7300, Frame count: 203741, Running reward: 3.45
# Episode: 7310, Frame count: 203897, Running reward: 3.58
# Episode: 7320, Frame count: 204067, Running reward: 3.65
# Episode: 7330, Frame count: 204230, Running reward: 3.75
# Episode: 7340, Frame count: 204393, Running reward: 3.73
# Episode: 7350, Frame count: 204556, Running reward: 3.53
# Episode: 7360, Frame count: 204723, Running reward: 3.5
# Episode: 7370, Frame count: 204881, Running reward: 3.58
# Episode: 7380, Frame count: 205055, Running reward: 3.58
# Episode: 7390, Frame count: 205227, Running reward: 3.5
# Episode: 7400, Frame count: 205380, Running reward: 3.61
# Episode: 7410, Frame count: 205542, Running reward: 3.55
# Episode: 7420, Frame count: 205715, Running reward: 3.52
# Episode: 7430, Frame count: 205873, Running reward: 3.57
# Episode: 7440, Frame count: 206050, Running reward: 3.43
# Episode: 7450, Frame count: 206200, Running reward: 3.56
# Episode: 7460, Frame count: 206372, Running reward: 3.51
# Episode: 7470, Frame count: 206538, Running reward: 3.43
# Episode: 7480, Frame count: 206704, Running reward: 3.51
# Episode: 7490, Frame count: 206862, Running reward: 3.65
# Episode: 7500, Frame count: 207031, Running reward: 3.49
# Episode: 7510, Frame count: 207195, Running reward: 3.47
# Episode: 7520, Frame count: 207350, Running reward: 3.65
# Episode: 7530, Frame count: 207508, Running reward: 3.65
# Episode: 7540, Frame count: 207673, Running reward: 3.77
# Episode: 7550, Frame count: 207826, Running reward: 3.74
# Episode: 7560, Frame count: 207993, Running reward: 3.79
# Episode: 7570, Frame count: 208160, Running reward: 3.78
# Episode: 7580, Frame count: 208312, Running reward: 3.92
# Episode: 7590, Frame count: 208474, Running reward: 3.88
# Episode: 7600, Frame count: 208624, Running reward: 4.07
# Episode: 7610, Frame count: 208800, Running reward: 3.95
# Episode: 7620, Frame count: 208972, Running reward: 3.78
# Episode: 7630, Frame count: 209128, Running reward: 3.8
# Episode: 7640, Frame count: 209303, Running reward: 3.7
# Episode: 7650, Frame count: 209449, Running reward: 3.77
# Episode: 7660, Frame count: 209609, Running reward: 3.84
# Episode: 7670, Frame count: 209755, Running reward: 4.05
# Episode: 7680, Frame count: 209920, Running reward: 3.92
# Episode: 7690, Frame count: 210081, Running reward: 3.93
# Episode: 7700, Frame count: 210248, Running reward: 3.76
# Episode: 7710, Frame count: 210397, Running reward: 4.03
# Episode: 7720, Frame count: 210545, Running reward: 4.27
# Episode: 7730, Frame count: 210716, Running reward: 4.12
# Episode: 7740, Frame count: 210872, Running reward: 4.31
# Episode: 7750, Frame count: 211045, Running reward: 4.04
# Episode: 7760, Frame count: 211203, Running reward: 4.06
# Episode: 7770, Frame count: 211365, Running reward: 3.9
# Episode: 7780, Frame count: 211518, Running reward: 4.02
# Episode: 7790, Frame count: 211690, Running reward: 3.91
# Episode: 7800, Frame count: 211845, Running reward: 4.03
# Episode: 7810, Frame count: 211999, Running reward: 3.98
# Episode: 7820, Frame count: 212154, Running reward: 3.91
# Episode: 7830, Frame count: 212326, Running reward: 3.9
# Episode: 7840, Frame count: 212481, Running reward: 3.91
# Episode: 7850, Frame count: 212641, Running reward: 4.04
# Episode: 7860, Frame count: 212818, Running reward: 3.85
# Episode: 7870, Frame count: 212990, Running reward: 3.75
# Episode: 7880, Frame count: 213151, Running reward: 3.67
# Episode: 7890, Frame count: 213316, Running reward: 3.74
# Episode: 7900, Frame count: 213490, Running reward: 3.55
# Episode: 7910, Frame count: 213650, Running reward: 3.49
# Episode: 7920, Frame count: 213822, Running reward: 3.32
# Episode: 7930, Frame count: 213973, Running reward: 3.53
# Episode: 7940, Frame count: 214134, Running reward: 3.47
# Episode: 7950, Frame count: 214304, Running reward: 3.37
# Episode: 7960, Frame count: 214462, Running reward: 3.56
# Episode: 7970, Frame count: 214617, Running reward: 3.73
# Episode: 7980, Frame count: 214795, Running reward: 3.56
# Episode: 7990, Frame count: 214958, Running reward: 3.58
# Episode: 8000, Frame count: 215111, Running reward: 3.79
# Episode: 8010, Frame count: 215296, Running reward: 3.54
# Episode: 8020, Frame count: 215465, Running reward: 3.57
# Episode: 8030, Frame count: 215622, Running reward: 3.51
# Episode: 8040, Frame count: 215807, Running reward: 3.27
# Episode: 8050, Frame count: 215975, Running reward: 3.29
# Episode: 8060, Frame count: 216153, Running reward: 3.09
# Episode: 8070, Frame count: 216350, Running reward: 2.67
# Episode: 8080, Frame count: 216520, Running reward: 2.75
# Episode: 8090, Frame count: 216669, Running reward: 2.89
# Episode: 8100, Frame count: 216835, Running reward: 2.76
# Episode: 8110, Frame count: 216993, Running reward: 3.03
# Episode: 8120, Frame count: 217169, Running reward: 2.96
# Episode: 8130, Frame count: 217331, Running reward: 2.91
# Episode: 8140, Frame count: 217494, Running reward: 3.13
# Episode: 8150, Frame count: 217651, Running reward: 3.24
# Episode: 8160, Frame count: 217810, Running reward: 3.43
# Episode: 8170, Frame count: 217964, Running reward: 3.86
# Episode: 8180, Frame count: 218116, Running reward: 4.04
# Episode: 8190, Frame count: 218290, Running reward: 3.79
# Episode: 8200, Frame count: 218457, Running reward: 3.78
# Episode: 8210, Frame count: 218618, Running reward: 3.75
# Episode: 8220, Frame count: 218763, Running reward: 4.06
# Episode: 8230, Frame count: 218924, Running reward: 4.07
# Episode: 8240, Frame count: 219088, Running reward: 4.06
# Episode: 8250, Frame count: 219254, Running reward: 3.97
# Episode: 8260, Frame count: 219420, Running reward: 3.9
# Episode: 8270, Frame count: 219595, Running reward: 3.69
# Episode: 8280, Frame count: 219768, Running reward: 3.48
# Episode: 8290, Frame count: 219930, Running reward: 3.6
# Episode: 8300, Frame count: 220093, Running reward: 3.64
# Episode: 8310, Frame count: 220249, Running reward: 3.69
# Episode: 8320, Frame count: 220411, Running reward: 3.52
# Episode: 8330, Frame count: 220578, Running reward: 3.46
# Episode: 8340, Frame count: 220728, Running reward: 3.6
# Episode: 8350, Frame count: 220881, Running reward: 3.73
# Episode: 8360, Frame count: 221026, Running reward: 3.94
# Episode: 8370, Frame count: 221193, Running reward: 4.02
# Episode: 8380, Frame count: 221351, Running reward: 4.17
# Episode: 8390, Frame count: 221503, Running reward: 4.27
# Episode: 8400, Frame count: 221663, Running reward: 4.3
# Episode: 8410, Frame count: 221809, Running reward: 4.4
# Episode: 8420, Frame count: 221958, Running reward: 4.53
# Episode: 8430, Frame count: 222116, Running reward: 4.62
# Episode: 8440, Frame count: 222273, Running reward: 4.55
# Episode: 8450, Frame count: 222430, Running reward: 4.51
# Episode: 8460, Frame count: 222580, Running reward: 4.46
# Episode: 8470, Frame count: 222750, Running reward: 4.43
# Episode: 8480, Frame count: 222910, Running reward: 4.41
# Episode: 8490, Frame count: 223062, Running reward: 4.41
# Episode: 8500, Frame count: 223222, Running reward: 4.41
# Episode: 8510, Frame count: 223400, Running reward: 4.09
# Episode: 8520, Frame count: 223570, Running reward: 3.88
# Episode: 8530, Frame count: 223739, Running reward: 3.77
# Episode: 8540, Frame count: 223899, Running reward: 3.74
# Episode: 8550, Frame count: 224066, Running reward: 3.64
# Episode: 8560, Frame count: 224231, Running reward: 3.49
# Episode: 8570, Frame count: 224393, Running reward: 3.57
# Episode: 8580, Frame count: 224551, Running reward: 3.59
# Episode: 8590, Frame count: 224706, Running reward: 3.56
# Episode: 8600, Frame count: 224871, Running reward: 3.51
# Episode: 8610, Frame count: 225035, Running reward: 3.65
# Episode: 8620, Frame count: 225192, Running reward: 3.78
# Episode: 8630, Frame count: 225358, Running reward: 3.81
# Episode: 8640, Frame count: 225527, Running reward: 3.72
# Episode: 8650, Frame count: 225674, Running reward: 3.92
# Episode: 8660, Frame count: 225832, Running reward: 3.99
# Episode: 8670, Frame count: 225986, Running reward: 4.07
# Episode: 8680, Frame count: 226153, Running reward: 3.98
# Episode: 8690, Frame count: 226298, Running reward: 4.08
# Episode: 8700, Frame count: 226449, Running reward: 4.22
# Episode: 8710, Frame count: 226605, Running reward: 4.3
# Episode: 8720, Frame count: 226774, Running reward: 4.18
# Episode: 8730, Frame count: 226938, Running reward: 4.2
# Episode: 8740, Frame count: 227097, Running reward: 4.3
# Episode: 8750, Frame count: 227248, Running reward: 4.26
# Episode: 8760, Frame count: 227420, Running reward: 4.12
# Episode: 8770, Frame count: 227569, Running reward: 4.17
# Episode: 8780, Frame count: 227731, Running reward: 4.22
# Episode: 8790, Frame count: 227868, Running reward: 4.3
# Episode: 8800, Frame count: 228027, Running reward: 4.22
# Episode: 8810, Frame count: 228199, Running reward: 4.06
# Episode: 8820, Frame count: 228359, Running reward: 4.15
# Episode: 8830, Frame count: 228512, Running reward: 4.26
# Episode: 8840, Frame count: 228670, Running reward: 4.27
# Episode: 8850, Frame count: 228838, Running reward: 4.1
# Episode: 8860, Frame count: 228984, Running reward: 4.36
# Episode: 8870, Frame count: 229169, Running reward: 4.0
# Episode: 8880, Frame count: 229317, Running reward: 4.14
# Episode: 8890, Frame count: 229462, Running reward: 4.06
# Episode: 8900, Frame count: 229639, Running reward: 3.88
# Episode: 8910, Frame count: 229804, Running reward: 3.95
# Episode: 8920, Frame count: 229978, Running reward: 3.81
# Episode: 8930, Frame count: 230148, Running reward: 3.64
# Episode: 8940, Frame count: 230328, Running reward: 3.42
# Episode: 8950, Frame count: 230496, Running reward: 3.42
# Episode: 8960, Frame count: 230646, Running reward: 3.38
# Episode: 8970, Frame count: 230803, Running reward: 3.66
# Episode: 8980, Frame count: 230958, Running reward: 3.59
# Episode: 8990, Frame count: 231113, Running reward: 3.49
# Episode: 9000, Frame count: 231265, Running reward: 3.74
# Episode: 9010, Frame count: 231425, Running reward: 3.79
# Episode: 9020, Frame count: 231592, Running reward: 3.86
# Episode: 9030, Frame count: 231742, Running reward: 4.06
# Episode: 9040, Frame count: 231912, Running reward: 4.16
# Episode: 9050, Frame count: 232061, Running reward: 4.35
# Episode: 9060, Frame count: 232207, Running reward: 4.39
# Episode: 9070, Frame count: 232367, Running reward: 4.36
# Episode: 9080, Frame count: 232525, Running reward: 4.33
# Episode: 9090, Frame count: 232684, Running reward: 4.29
# Episode: 9100, Frame count: 232837, Running reward: 4.28
# Episode: 9110, Frame count: 232989, Running reward: 4.36
# Episode: 9120, Frame count: 233145, Running reward: 4.47
# Episode: 9130, Frame count: 233293, Running reward: 4.49
# Episode: 9140, Frame count: 233463, Running reward: 4.49
# Episode: 9150, Frame count: 233632, Running reward: 4.29
# Episode: 9160, Frame count: 233789, Running reward: 4.18
# Episode: 9170, Frame count: 233948, Running reward: 4.19
# Episode: 9180, Frame count: 234115, Running reward: 4.1
# Episode: 9190, Frame count: 234279, Running reward: 4.05
# Episode: 9200, Frame count: 234434, Running reward: 4.03
# Episode: 9210, Frame count: 234587, Running reward: 4.02
# Episode: 9220, Frame count: 234739, Running reward: 4.06
# Episode: 9230, Frame count: 234883, Running reward: 4.1
# Episode: 9240, Frame count: 235045, Running reward: 4.18
# Episode: 9250, Frame count: 235197, Running reward: 4.35
# Episode: 9260, Frame count: 235360, Running reward: 4.29
# Episode: 9270, Frame count: 235516, Running reward: 4.32
# Episode: 9280, Frame count: 235672, Running reward: 4.43
# Episode: 9290, Frame count: 235836, Running reward: 4.43
# Episode: 9300, Frame count: 236011, Running reward: 4.23
# Episode: 9310, Frame count: 236175, Running reward: 4.12
# Episode: 9320, Frame count: 236345, Running reward: 3.94
# Episode: 9330, Frame count: 236513, Running reward: 3.7
# Episode: 9340, Frame count: 236679, Running reward: 3.66
# Episode: 9350, Frame count: 236839, Running reward: 3.58
# Episode: 9360, Frame count: 236992, Running reward: 3.68
# Episode: 9370, Frame count: 237155, Running reward: 3.61
# Episode: 9380, Frame count: 237319, Running reward: 3.53
# Episode: 9390, Frame count: 237459, Running reward: 3.77
# Episode: 9400, Frame count: 237628, Running reward: 3.83
# Episode: 9410, Frame count: 237778, Running reward: 3.97
# Episode: 9420, Frame count: 237921, Running reward: 4.24
# Episode: 9430, Frame count: 238088, Running reward: 4.25
# Episode: 9440, Frame count: 238264, Running reward: 4.15
# Episode: 9450, Frame count: 238429, Running reward: 4.1
# Episode: 9460, Frame count: 238600, Running reward: 3.92
# Episode: 9470, Frame count: 238742, Running reward: 4.13
# Episode: 9480, Frame count: 238912, Running reward: 4.07
# Episode: 9490, Frame count: 239074, Running reward: 3.85
# Episode: 9500, Frame count: 239225, Running reward: 4.03
# Episode: 9510, Frame count: 239389, Running reward: 3.89
# Episode: 9520, Frame count: 239553, Running reward: 3.68
# Episode: 9530, Frame count: 239702, Running reward: 3.86
# Episode: 9540, Frame count: 239852, Running reward: 4.12
# Episode: 9550, Frame count: 239997, Running reward: 4.32
# Episode: 9560, Frame count: 240148, Running reward: 4.52
# Episode: 9570, Frame count: 240309, Running reward: 4.33
# Episode: 9580, Frame count: 240467, Running reward: 4.45
# Episode: 9590, Frame count: 240612, Running reward: 4.62
# Episode: 9600, Frame count: 240774, Running reward: 4.51
# Episode: 9610, Frame count: 240919, Running reward: 4.7
# Episode: 9620, Frame count: 241084, Running reward: 4.69
# Episode: 9630, Frame count: 241253, Running reward: 4.49
# Episode: 9640, Frame count: 241413, Running reward: 4.39
# Episode: 9650, Frame count: 241563, Running reward: 4.34
# Episode: 9660, Frame count: 241712, Running reward: 4.36
# Episode: 9670, Frame count: 241862, Running reward: 4.47
# Episode: 9680, Frame count: 242021, Running reward: 4.46
# Episode: 9690, Frame count: 242199, Running reward: 4.13
# Episode: 9700, Frame count: 242350, Running reward: 4.24
# Episode: 9710, Frame count: 242506, Running reward: 4.13
# Episode: 9720, Frame count: 242661, Running reward: 4.23
# Episode: 9730, Frame count: 242808, Running reward: 4.45
# Episode: 9740, Frame count: 242971, Running reward: 4.42
# Episode: 9750, Frame count: 243117, Running reward: 4.46
# Episode: 9760, Frame count: 243284, Running reward: 4.28
# Episode: 9770, Frame count: 243442, Running reward: 4.2
# Episode: 9780, Frame count: 243591, Running reward: 4.3
# Episode: 9790, Frame count: 243742, Running reward: 4.57
# Episode: 9800, Frame count: 243892, Running reward: 4.58
# Episode: 9810, Frame count: 244043, Running reward: 4.63
# Episode: 9820, Frame count: 244204, Running reward: 4.57
# Episode: 9830, Frame count: 244364, Running reward: 4.44
# Episode: 9840, Frame count: 244523, Running reward: 4.48
# Episode: 9850, Frame count: 244680, Running reward: 4.37
# Episode: 9860, Frame count: 244834, Running reward: 4.5
# Episode: 9870, Frame count: 244997, Running reward: 4.45
# Episode: 9880, Frame count: 245154, Running reward: 4.37
# Episode: 9890, Frame count: 245306, Running reward: 4.36
# Episode: 9900, Frame count: 245472, Running reward: 4.2
# Episode: 9910, Frame count: 245619, Running reward: 4.24
# Episode: 9920, Frame count: 245765, Running reward: 4.39
# Episode: 9930, Frame count: 245922, Running reward: 4.42
# Episode: 9940, Frame count: 246088, Running reward: 4.35
# Episode: 9950, Frame count: 246233, Running reward: 4.47
# Episode: 9960, Frame count: 246394, Running reward: 4.4
# Episode: 9970, Frame count: 246564, Running reward: 4.33
# Episode: 9980, Frame count: 246715, Running reward: 4.39
# Episode: 9990, Frame count: 246857, Running reward: 4.49
# Episode: 10000, Frame count: 247002, Running reward: 4.7
# Episode: 10010, Frame count: 247171, Running reward: 4.48

# %% [markdown]
# # Evaluation

# %%
import time, sys
from IPython.display import clear_output

board, info = env.reset()
state = preprocess_state(board)
action_mask = info['action_mask'].reshape((-1,))
done = False
env.render()

while not done:
    action = get_greedy_action(model, state.to(device), action_mask)
    print("action: ({}, {})".format(action // 8, action % 8))
    sys.stdout.flush()

    time.sleep(1.0)
    clear_output(wait=False)
    board, reward, done, info = env.step((action // 8, action % 8))
    state = preprocess_state(board)
    action_mask = info['action_mask'].reshape((-1,))
    env.render()
# Out:
#          |
#  M   H   |      H
#    HMH   |    H H
#    HHHH  |    HHHH
#   MH HM  |    H H
#    M H   |      H
#      M   |
#          |
